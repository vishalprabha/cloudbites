# %%
# installing missing dependencies
import warnings
warnings.filterwarnings('ignore')
# !pip3 install pandas
# !pip3 install string
# !pip3 install nltk
# !pip3 install wordcloud
# !pip3 install PIL
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.1.2; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement string (from versions: none)
# ERROR: No matching distribution found for string
# WARNING: You are using pip version 21.1.2; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.1.2; however, version 22.0.4 is available.
# ...

# %%
# imports
import numpy as np
# import pandas as pd
# Preprocessing
import string
import io 
# import nltk
# from nltk.corpus import stopwords
# %matplotlib inline
# Generate word cloud image
import matplotlib.pyplot as plt
from wordcloud.wordcloud import WordCloud
from PIL import Image
import base64

# %%
# downloading stop words
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/viprabha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# reading reviews data locally to analyze
yelp = pd.read_json('/Users/viprabha/Downloads/yelp_dataset/yelp_academic_dataset_review.json', lines=True)

# %%
# priniting contents
yelp.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# ...

# %%
# working on sample response from elastic search

api_response = [
    {
        "date": {
            "raw": "2016-06-02 23:00:37"
        },
        "review_id": {
            "raw": "u37-cfsnAD3T5h_rjap1Ng"
        },
        "user_id": {
            "raw": "Bdk_7Tvhiph-1Nwuf9KBjw"
        },
        "cool": {
            "raw": "0"
        },
        "stars": {
            "raw": "5.0"
        },
        "text": {
            "raw": "I knew I wanted 3m Crystalline on my new Tesla, so I did my research and decided to take it to Orange. They were professional, prompt, pleasant, and had my car done when they said they would. I even got cleaner, a microfiber cloth and cleaning wipes in a little gift bag! Very nice touch, Orange Tint, and I'm very happy with the tint job!"
        },
        "_meta": {
            "id": "doc-6255e528a4ae3c60e52489ac",
            "engine": "reviews",
            "score": 1.0
        },
        "id": {
            "raw": "doc-6255e528a4ae3c60e52489ac"
        },
        "business_id": {
            "raw": "CmjvsiafnWH60fuYz2LCmA"
        },
        "useful": {
            "raw": "0"
        },
        "funny": {
            "raw": "0"
        }
    },
    {
        "date": {
            "raw": "2016-06-12 22:18:53"
        },
        "review_id": {
            "raw": "0KEDu4NN4F8gLLh_zR0tzA"
        },
        "user_id": {
            "raw": "wxfdnAMj_9TaN7PHp1wVSA"
        },
        "cool": {
            "raw": "0"
        },
        "stars": {
            "raw": "5.0"
        },
        "text": {
            "raw": "Looked around for a quality tint shop, and decided on Orange Tint and Tunes because of the positive reviews.  I wasn't disappointed!  The business was very professional, but with a friendly family feel.  Everyone was very knowledgable, offered great suggestions.  They did a fantastic job tinting the windows and the sunroof of our brand new Audi Q5.  I drove 45 minutes from New Tampa and it was worth the trip.  If you desire quality products from a quality business, this is the place to go.  Will definitely be returning for future vehicles."
        },
        "_meta": {
            "id": "doc-6255e524a4ae3cd7ae24866d",
            "engine": "reviews",
            "score": 1.0
        },
        "id": {
            "raw": "doc-6255e524a4ae3cd7ae24866d"
        },
        "business_id": {
            "raw": "CmjvsiafnWH60fuYz2LCmA"
        },
        "useful": {
            "raw": "0"
        },
        "funny": {
            "raw": "0"
        }
    },
    {
        "date": {
            "raw": "2018-06-19 21:18:49"
        },
        "review_id": {
            "raw": "jaNAG0n28S6wbdEfvh3_CA"
        },
        "user_id": {
            "raw": "6gNcVGCQL8My2grmmUmMsQ"
        },
        "cool": {
            "raw": "0"
        },
        "stars": {
            "raw": "5.0"
        },
        "text": {
            "raw": "Great customer service. The installation was quick and good quality. I would certainly recommend to family and friends."
        },
        "_meta": {
            "id": "doc-6255e514a4ae3c7846247cfd",
            "engine": "reviews",
            "score": 1.0
        },
        "id": {
            "raw": "doc-6255e514a4ae3c7846247cfd"
        },
        "business_id": {
            "raw": "CmjvsiafnWH60fuYz2LCmA"
        },
        "useful": {
            "raw": "0"
        },
        "funny": {
            "raw": "0"
        }
    },
    {
        "date": {
            "raw": "2018-05-09 03:49:32"
        },
        "review_id": {
            "raw": "09FD8HXaCf9LxgM2GGBNtg"
        },
        "user_id": {
            "raw": "EjbVbeS2mQjKWu31q3H76A"
        },
        "cool": {
            "raw": "0"
        },
        "stars": {
            "raw": "5.0"
        },
        "text": {
            "raw": "Had my side and rear windows tinted with their top product. There was a big sign in the waiting room that said there is no perfect job. Well, as far as I can tell there is and I got it. They took the time to explain the options and let me see it on their own cars. It took less time than then stated which was a good thing. I was very cautious  not to roll down the windows for the first week and have had no issues. Highly recommended, very professional."
        },
        "_meta": {
            "id": "doc-6255e50ba4ae3c616a247700",
            "engine": "reviews",
            "score": 1.0
        },
        "id": {
            "raw": "doc-6255e50ba4ae3c616a247700"
        },
        "business_id": {
            "raw": "CmjvsiafnWH60fuYz2LCmA"
        },
        "useful": {
            "raw": "1"
        },
        "funny": {
            "raw": "0"
        }
    },
    {
        "date": {
            "raw": "2015-07-16 19:51:27"
        },
        "review_id": {
            "raw": "xYU8dPZ34mydpDz5L-BgjQ"
        },
        "user_id": {
            "raw": "HgIiusjpJ5tqtTUen-iQ2A"
        },
        "cool": {
            "raw": "0"
        },
        "stars": {
            "raw": "5.0"
        },
        "text": {
            "raw": "This place is the bomb! Brought two of my cars here, and couldn't of been more satisfied! Rosemary is very nice and will answer any question you have very professionally. This place is very cool looking inside and out, and have very talented people performing the work. The price is also the best around and they warranty any work they do!  They don't try and sell you stuff you don't need either. These people have great reviews for a reason, and I'm happy I chose them for my window tint!! Please don't waste your time with any other window tinting business!! Rosemary and her team is the ONLY way to go!"
        },
        "_meta": {
            "id": "doc-6255e46ba4ae3cbc77243987",
            "engine": "reviews",
            "score": 1.0
        },
        "id": {
            "raw": "doc-6255e46ba4ae3cbc77243987"
        },
        "business_id": {
            "raw": "CmjvsiafnWH60fuYz2LCmA"
        },
        "useful": {
            "raw": "1"
        },
        "funny": {
            "raw": "0"
        }
    },
    {
        "date": {
            "raw": "2015-11-18 22:25:22"
        },
        "review_id": {
            "raw": "A6RyprhBtUtanSuzPfa0wg"
        },
        "user_id": {
            "raw": "88Z1DbloWrT7g8GA5qOrng"
        },
        "cool": {
            "raw": "0"
        },
        "stars": {
            "raw": "5.0"
        },
        "text": {
            "raw": "Recently had my car tinted by Orange Tint and Tune and had fantastic service.  They offer a car pick up service if you live within 4 miles of their shop which is extremely convenient.  Carlos was my technician and went over all the tint options with me and even adjusted the grade of the tint after I expressed the look that I was trying to achieve.  That's the kind of customer care that deserves 5 stars.  In addition, the receptionist was very pleasant and the owner Dustin even followed up to see how my service was."
        },
        "_meta": {
            "id": "doc-6255e434a4ae3cbc772416ac",
            "engine": "reviews",
            "score": 1.0
        },
        "id": {
            "raw": "doc-6255e434a4ae3cbc772416ac"
        },
        "business_id": {
            "raw": "CmjvsiafnWH60fuYz2LCmA"
        },
        "useful": {
            "raw": "0"
        },
        "funny": {
            "raw": "0"
        }
    }
]

# %%
# concatenating all the reviews
text = ''
for element in api_response:
    text += element["text"]["raw"]

print(text)
# Out:
# I knew I wanted 3m Crystalline on my new Tesla, so I did my research and decided to take it to Orange. They were professional, prompt, pleasant, and had my car done when they said they would. I even got cleaner, a microfiber cloth and cleaning wipes in a little gift bag! Very nice touch, Orange Tint, and I'm very happy with the tint job!Looked around for a quality tint shop, and decided on Orange Tint and Tunes because of the positive reviews.  I wasn't disappointed!  The business was very professional, but with a friendly family feel.  Everyone was very knowledgable, offered great suggestions.  They did a fantastic job tinting the windows and the sunroof of our brand new Audi Q5.  I drove 45 minutes from New Tampa and it was worth the trip.  If you desire quality products from a quality business, this is the place to go.  Will definitely be returning for future vehicles.Great customer service. The installation was quick and good quality. I would certainly recommend to family and fri
# ...

# %%
# preprocessing the reviews


# remove numbers
def remove_num(text):
    text = ''.join([i for i in text if not i.isdigit()])
    return text

# remove punctuation
from string import punctuation
def remove_punct(text):
    text = ' '.join(word.strip(punctuation) for word in text.split() if word.strip(punctuation))
    return text

# remove other characters
def remove_u(text):
    text = text.replace('_','')
    text = text.replace('?','')
    text = text.replace('•','')
    text = text.replace("@",'')
    text = text.replace('▯','')
    text = text.replace("'",'')
    text = text.replace(",","")
    return text

# remove extra spaces
def remove_extra_space(text):
    word_list = text.split()
    text = ' '.join(word_list)
    return text

# remove common words
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the","Mr", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]
def remove_stopwords(text):
    word_list = text.split()
    word_list = [word for word in word_list if word.lower() not in stop_words]
    text = ' '.join(word_list)
    return text

text = np.vectorize(remove_num)(text)
text = np.vectorize(remove_punct)(text)
text = np.vectorize(remove_u)(text)
text = np.vectorize(remove_extra_space)(text)
text = np.vectorize(remove_stopwords)(text)
text = text.tolist()
print(text)
# Out:
# knew wanted m Crystalline new Tesla research decided take Orange professional prompt pleasant car done said would even got cleaner microfiber cloth cleaning wipes little gift bag nice touch Orange Tint Im happy tint job!Looked around quality tint shop decided Orange Tint Tunes positive reviews wasnt disappointed business professional friendly family feel Everyone knowledgable offered great suggestions fantastic job tinting windows sunroof brand new Audi Q drove minutes New Tampa worth trip desire quality products quality business place go definitely returning future vehicles.Great customer service installation quick good quality would certainly recommend family friends.Had side rear windows tinted top product big sign waiting room said perfect job Well far tell got took time explain options let see cars took less time stated good thing cautious roll windows first week issues Highly recommended professional.This place bomb Brought two cars couldnt satisfied Rosemary nice answer questi
# ...

# %%
mask_image = np.array(Image.open("cloud.png"))

def transform_format(val):
    if val == 0:
        return 255
    else:
        return val
    
transformed_cloud = np.ndarray((mask_image.shape[0],mask_image.shape[1]), np.int32)

for i in range(len(mask_image)):
    transformed_cloud[i] = list(map(transform_format, mask_image[i]))
wordcloud_good = WordCloud(colormap = "Paired",mask = transformed_cloud, width = 300, height = 200, scale=2,max_words=1000).generate(text)

# plt.figure(figsize = (7,10))
# plt.imshow(wordcloud_good, interpolation="bilinear", cmap = plt.cm.autumn)
# plt.axis('off')
# pic_IObytes = io.BytesIO()
# plt.savefig(pic_IObytes, format='png')
# plt.close()
# pic_IObytes.seek(0)
# plot_url = base64.b64encode(pic_IObytes.getvalue()).decode('utf8')
# print(plot_url)


buffer = io.BytesIO()
wordcloud_good.to_image().save(buffer, 'png')
b64 = base64.b64encode(buffer.getvalue()).decode('utf8')
print(b64)
# plt.show()
# Out:
# ...

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1> \
 <img src="......"/>\
             '))
# Out:
# <h1>Hello, world!</h1>  <img src="......"/>
